# %% [markdown]
# # CapeStone Project

# %% [markdown]
# # IBDM Dataset

# %% [markdown]
# # Name: Harshit Tripathi

# %% [markdown]
# # Batch: DS0822

# %% [markdown]
# ## Phase 1

# %% [markdown]
# 1) Webscrape the provided URL  - IMDB dataset:
#
# https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1
#
#
#
# 2) Store the entire data in two different CSV files as per the given fields:
#
#
# The first CSV file data contains :
#
#
# Sno, Movie Name, Director Name, Duration, year, ratings, Metascore
#
#
# Bifurcate the Director field into subfields as per the number of directors of the movie belongs to such as Director1, director2
#
#
# The second CSV file contains the following:
#
#
# Movie Name, stars, votes, Genre, Gross collection, popularity, Certification
#
#
# Bifurcate the stars field into 4 subfields as per the number of stars worked in the movie such as star1, star2, star3, star4
#
#
# Bifurcate the genre into 3 subfields as per the number of genres the movie belongs to such as :
#
#
# Genre1, genre2, genre3

# %%
#Import all necessary libraries 

import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import pandas as pd
import numpy as np
import time
import warnings 
warnings.filterwarnings('ignore')

# %%
#Connecting to the driver
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
#Opening the URL on automated chrome browser 
driver.get('https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1')

# %%
#Creating list of all the items that we have to scrape
s_no=[]
movie_name=[]
director_name=[]
duration=[]
year=[]
ratings=[]
metascore=[]

# %%
#scrapping serial number from web page
while True:
    serno = driver.find_elements(By.XPATH, '//span[@class="lister-item-index unbold text-primary"]')
    for i in serno:
        #Extract the text from the item element
        s_no.append(i.text)
    try:
        # Find the "Next" button and click on it
        next_button = driver.find_element(By.XPATH, '//a[@class="lister-page-next next-page"]')
        next_button.click()
        time.sleep(3)
    except NoSuchElementException:
        break  # Break the loop if the "Next" button is not found

# %%
len(s_no)
# Out:
# 1764

# %%
#getting back to the first page
desired_page = 37

for _ in range(desired_page - 1):
    try:
        previous_button = driver.find_element(By.XPATH, '//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
#Scraping movie name from the web page

while True:
    mname=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]')
    for i in mname:
        #Extract the text from the item element
        i=i.text.split("(")[0]
        i=i.split(".")[1]
        movie_name.append(i)
    try:
        #Find Next button and click on it
        next_button = driver.find_element(By.XPATH, '//a[@class="lister-page-next next-page"]')
        next_button.click()
        time.sleep(3)
    except NoSuchElementException:
        break

# %%
len(movie_name)
# Out:
# 1764

# %%
#getting back to the first page
desired_page = 37

for _ in range(desired_page - 1):
    try:
        previous_button = driver.find_element(By.XPATH, '//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
#Scraping duration from web page

while True:
    dur=driver.find_elements(By.XPATH,'//span[@class="runtime"]')
    
    for i in  dur:
        #Extract the text from the item element
        dura=i.text.split(" ")[0]
        duration.append(dura)
        
    try:
        # Find the "Next" button and click on it
        next_button = driver.find_element(By.XPATH, '//a[@class="lister-page-next next-page"]')
        next_button.click()
        
    except NoSuchElementException:
        break

# %%
len(duration)
# Out:
# 1764

# %%
#getting back to the first page
desired_page = 37

for _ in range(desired_page - 1):
    try:
        previous_button = driver.find_element(By.XPATH, '//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
#scraping year information from the web page

while True:
    ye=driver.find_elements(By.XPATH,'//span[@class="lister-item-year text-muted unbold"]')
    
    for i in ye:
        yea=i.text.split
        year.append(i.text)
        
    try:
        # Find the "Next" button and click on it
        next_button=driver.find_element(By.XPATH,'//a[@class="lister-page-next next-page"]')
        next_button.click()
        time.sleep(3)
    except NoSuchElementException:
        break

# %%
len(year)
# Out:
# 1764

# %%
#getting back to the first page
desired_page = 37

for _ in range(desired_page - 1):
    try:
        previous_button = driver.find_element(By.XPATH, '//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
#scrapping ratings from the web page 
while True:
    rat = driver.find_elements(By.XPATH, '//div[@class="inline-block ratings-imdb-rating"]')
    for i in rat:
        # Extract the text from the item element
        ratings.append(i.text)
    try:
        # Find the "Next" button and click on it
        next_button = driver.find_element(By.XPATH, '//a[@class="lister-page-next next-page"]')
        next_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
len(ratings)
# Out:
# 1764

# %%
#Getting back to the first page

desired_page=37

for _ in range(desired_page -1):
    try:
        previous_button=driver.find_element(By.XPATH,'//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
#scraping directors data from the web page

while True:
    dire=driver.find_elements(By.XPATH,'//p[@class=""]')
    
    for i in dire:
        # Extract the text from the item element
        dr=i.text.split("|")[0].split(":")[1]
        director_name.append(dr)
        
    try:
        # Find the "Next" button and click on it
        next_button=driver.find_element(By.XPATH,'//a[@class="lister-page-next next-page"]')
        next_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
len(director_name)
# Out:
# 1764

# %%
#Getting back to the first page

desired_page=37

for _ in range(desired_page -1):
    try:
        previous_button=driver.find_element(By.XPATH,'//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %% [markdown]
# Bifurcate the Director field into subfields

# %%
#checking maximum number of directors in one movie
max_values = 0

for row in director_name:
    values = row.split(",")
    num_values = len(values)
    if num_values > max_values:
        max_values = num_values

print("Maximum number of values in a row:", max_values)
# Out:
# Maximum number of values in a row: 6

# %%
#as we can see we have maximum of 6 directors in any movie, so lets create 6 empty lists to store them
dir_1=[]
dir_2=[]
dir_3=[]
dir_4=[]
dir_5=[]
dir_6=[]

#scrapping directors
while True:
    dire = driver.find_elements(By.XPATH, '//p[@class=""]')
    for i in dire:
        # Extract the text from the item element
        dirr=i.text.split("|")[0].split(":")[1].split(",")
        
        dir1=dirr[0]
        dir_1.append(dir1)
        
        dir2=dirr[1] if len(dirr)>1 else 'N/A'
        dir_2.append(dir2)
        
        dir3=dirr[2] if len(dirr)>2 else 'N/A'
        dir_3.append(dir3)
        
        dir4=dirr[3] if len(dirr)>3 else 'N/A'
        dir_4.append(dir4)
        
        dir5=dirr[4] if len(dirr)>4 else 'N/A'
        dir_5.append(dir5)
        
        dir6=dirr[5] if len(dirr)>5 else 'N/A'
        dir_6.append(dir6)
        
        
    try:
        # Find the "Next" button and click on it
        next_button = driver.find_element(By.XPATH, '//a[@class="lister-page-next next-page"]')
        next_button.click()
    except NoSuchElementException:
        break

# %%
#checking weather all items appended in list or not
print(len(dir_1))
print(len(dir_2))
print(len(dir_3))
print(len(dir_4))
print(len(dir_5))
print(len(dir_6))
# Out:
# 1764
# 1764
# 1764
# 1764
# 1764
# 1764

# %%
#Getting back to the first page

desired_page=37

for _ in range(desired_page -1):
    try:
        previous_button=driver.find_element(By.XPATH,'//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
#scraping Metascore values from the web page

while True:
    meta=driver.find_elements(By.XPATH,'//div[@class="ratings-bar"]')
    
    
    for i in meta:
            try:
                metascore.append(i.text.split("\n")[1].split(" ")[0])
            except:
                metascore.append("Nan")
    
    
    

        
    try:
        next_button=driver.find_element(By.XPATH,'//a[@class="lister-page-next next-page"]')
        next_button.click()
    except NoSuchElementException:
        break

# %%
len(metascore)
# Out:
# 1764

# %%
#Getting back to the first page

desired_page=37

for _ in range(desired_page -1):
    try:
        previous_button=driver.find_element(By.XPATH,'//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
#creating empty list to store gross collection
gross_collection=[]

#scrapping gross collection
while True:
    gc = driver.find_elements(By.XPATH, '//p[@class="sort-num_votes-visible"]')
    for i in gc:
        # Extract the text from the item element
        gross=i.text.split("|") if i.text.split("|") else "N/A"
        gross=gross[1].split(":")[1] if len(gross)>1 else "N/A"
        gross_collection.append(gross)
    try:
        # Find the "Next" button and click on it
        next_button = driver.find_element(By.XPATH, '//a[@class="lister-page-next next-page"]')
        next_button.click()
    except NoSuchElementException:
        break  # Break the loop if the "Next" button is not found

# %%
len(gross_collection)
# Out:
# 1764

# %%
#Getting back to the first page

desired_page=37

for _ in range(desired_page -1):
    try:
        previous_button=driver.find_element(By.XPATH,'//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
#scraping votes data From the we page


#creating an empty vote list to store the data
votes=[]


while True:
    vot=driver.find_elements(By.XPATH,'//p[@class="sort-num_votes-visible"]')
    for i in vot:
        # Extract the text from the item element
        votes.append(i.text.split(":")[1].split("|")[0])
        
    try:
        next_button=driver.find_element(By.XPATH,'//a[@class="lister-page-next next-page"]')
        next_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
len(votes)
# Out:
# 1764

# %%
#Getting back to the first page

desired_page=37

for _ in range(desired_page -1):
    try:
        previous_button=driver.find_element(By.XPATH,'//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
#creating empty list to store genre
all_genre=[]

#scrapping duration
while True:
    gen = driver.find_elements(By.XPATH, '//span[@class="genre"]')
    for i in gen:
        # Extract the text from the item element
        try:
                all_genre.append(i.text)
        except:
                all_genre.append("Nan")
                
        
    try:
        # Find the "Next" button and click on it
        next_button = driver.find_element(By.XPATH, '//a[@class="lister-page-next next-page"]')
        next_button.click()
    except NoSuchElementException:
        break  # Break the loop if the "Next" button is not found

# %%
len(all_genre)
# Out:
# 1764

# %%
#Getting back to the first page

desired_page=37

for _ in range(desired_page -1):
    try:
        previous_button=driver.find_element(By.XPATH,'//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
#checking what is the max number of elements in a row
max_values = 0

for i in all_genre:
    values = i.split(",")
    num_values = len(values)
    if num_values > max_values:
        max_values = num_values

print("Maximum number of values in a row:", max_values)
# Out:
# Maximum number of values in a row: 3

# %%
#creating three empty list to store genre as we know we have max of three genres in a movie
genre_1=[]
genre_2=[]
genre_3=[]

#scrapping genre
while True:
    gen = driver.find_elements(By.XPATH, '//span[@class="genre"]')
    for i in gen:
        # Extract the text from the item element
        genre_1.append(i.text.split(",")[0])
        try:
                genre_2.append(i.text.split(",")[1])
        except:
                genre_2.append("Nan")
        try:
                genre_3.append(i.text.split(",")[2])
        except:
                genre_3.append("Nan")
        
        
    try:
        # Find the "Next" button and click on it
        next_button = driver.find_element(By.XPATH, '//a[@class="lister-page-next next-page"]')
        next_button.click()
    except NoSuchElementException:
        break  # Break the loop if the "Next" button is not found

# %%
print(len(genre_1))
print(len(genre_2))
print(len(genre_3))
# Out:
# 1764
# 1764
# 1764

# %%
#Getting back to the first page

desired_page=37

for _ in range(desired_page -1):
    try:
        previous_button=driver.find_element(By.XPATH,'//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
#creating empty list to store stars name

stars=[]

#scraping star name values from the web page
while True:
    star=driver.find_elements(By.XPATH,'//p[@class=""]')
    for i in star:
        #Extract the text from the item element
        st=i.text.split("|")[1].split(":")[1]
        stars.append(st)
    try:
        next_button=driver.find_element(By.XPATH,'//a[@class="lister-page-next next-page"]')
        next_button.click()
    except NoSuchElementException:
        break

# %%
len(stars)
# Out:
# 1764

# %%
#Getting back to the first page

desired_page=37

for _ in range(desired_page -1):
    try:
        previous_button=driver.find_element(By.XPATH,'//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
max_values = 0

for i in stars:
    values = i.split(",")
    num_values = len(values)
    if num_values > max_values:
        max_values = num_values

print("Maximum number of values in a row:", max_values)
# Out:
# Maximum number of values in a row: 4

# %%
#as we can see we have maximum of 4 stars in any movie, so lets create 4 empty lists to store them
star_1=[]
star_2=[]
star_3=[]
star_4=[]

#scrapping stars
while True:
    star= driver.find_elements(By.XPATH, '//p[@class=""]')
    for i in star:
        # Extract the text from the item element
        starr=i.text.split("|")[1].split(":")[1].split(",")
        
        star1=starr[0]
        star_1.append(star1)
        
        star2=starr[1] if len(starr)>1 else "N/A"
        star_2.append(star2)
        
        star3=starr[2] if len(starr)>2 else "N/A"
        star_3.append(star3)
        
        star4=starr[3] if len(starr)>3 else "N/A"
        star_4.append(star4)
        
    try:
        # Find the "Next" button and click on it
        next_button = driver.find_element(By.XPATH, '//a[@class="lister-page-next next-page"]')
        next_button.click()
    except NoSuchElementException:
        break  # Break the loop if the "Next" button is not found

# %%
#checking weather all items appended in list or not
print(len(star_1))
print(len(star_2))
print(len(star_3))
print(len(star_4))
# Out:
# 1764
# 1764
# 1764
# 1764

# %%
#Getting back to the first page

desired_page=37

for _ in range(desired_page -1):
    try:
        previous_button=driver.find_element(By.XPATH,'//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
#scraping certification details from the web page

#creating an empty list to store the data
certification=[]

while True:
    certi=driver.find_elements(By.XPATH,'//span[@class="certificate"]')
    for i in certi:
        certification.append(i.text.split(":")[0].split("|")[0])
        certification.append(i.text)
        
    try:
        next_button=driver.find_element(By.XPATH,'//a[@class="lister-page-next next-page"]')
        next_button.click()
        time.sleep(3)
    except NoSuchElementException:
        break

# %%
certification=certification[:1764]

# %%
len(certification)
# Out:
# 1764

# %%
#Getting back to the first page

desired_page=37

for _ in range(desired_page -1):
    try:
        previous_button=driver.find_element(By.XPATH,'//a[@class="lister-page-prev prev-page"]')
        previous_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# %%
#Scraping popularity data from the web page 

#To extract popularity we have to firstly extract url of all movies popularity data is present inside of each movie page.

#create an empty list to store url
url=[]

#scraping urls

while True:
    url_movie =driver.find_elements(By.XPATH, '//h3[@class="lister-item-header"]//a')
    for i in url_movie:
        url.append(i.get_attribute("href"))
   
    try:
        next_button=driver.find_element(By.XPATH,'//a[@class="lister-page-next next-page"]')
        next_button.click()
        time.sleep(3)
    except NoSuchElementException:
        break

# %%
len(url)
# Out:
# 1764

# %%
popularity = []

for i in url:
    driver.get(i)

    try:
        pops = driver.find_elements(By.XPATH, '//div[@class="sc-5f7fb5b4-0 cUcPIU"]')
        
        for pop in pops:
            numerical_parts = [part for part in pop.text.split() if part.isdigit()]
            numerical_value = ''.join(numerical_parts).replace(',', '')
            popularity.append(numerical_value)
            
    except NoSuchElementException:
        popularity.append('nan')
        time.sleep(3)

# %%
len(popularity)
# Out:
# 2350

# %%
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')

# %%
len(popularity)
# Out:
# 1850

# %%
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')
popularity.remove('')

# %%
len(popularity)
# Out:
# 1760

# %%
s_no=s_no[:1760]
movie_name=movie_name[:1760]
director_name=director_name[:1760]
dir_1=dir_1[:1760]
dir_2=dir_2[:1760]
dir_3=dir_3[:1760]
dir_4=dir_4[:1760]
dir_5=dir_5[:1760]
dir_6=dir_6[:1760]
duration=duration[:1760]
year=year[:1760]
ratings=ratings[:1760]
metascore=metascore[:1760]
popularity=popularity[:1760]
certification=certification[:1760]
star_1=star_1[:1760]
star_2=star_2[:1760]
star_3=star_3[:1760]
star_4=star_4[:1760]
stars=stars[:1760]
genre_1=genre_1[:1760]
genre_2=genre_2[:1760]
genre_3=genre_3[:1760]
all_genre=all_genre[:1760]
votes=votes[:1760]
gross_collection=gross_collection[:1760]

# %%
print(len(s_no))
print(len(movie_name))
print(len(director_name))
print(len(dir_1))
print(len(dir_2))
print(len(dir_3))
print(len(dir_4))
print(len(dir_5))
print(len(dir_6))
print(len(duration))
print(len(year))
print(len(ratings))
print(len(metascore))
print(len(popularity))
print(len(certification))
print(len(star_1))
print(len(star_2))
print(len(star_3))
print(len(star_4))
print(len(stars))
print(len(genre_1))
print(len(genre_2))
print(len(genre_3))
print(len(all_genre))
print(len(votes))
print(len(gross_collection))
# Out:
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760
# 1760

# %% [markdown]
# #### count for each column is same so now we can make the DataFrame.

# %%
#creating first DataFrame 
df_1=pd.DataFrame({'Serial no.':s_no,'Movie Name':movie_name,'Director 1':dir_1,'Director 2':dir_2,'Director 3':dir_3,'Director 4':dir_4,'Director 5':dir_5,'Director 6':dir_6,'Duration':duration,'Year of Release':year,'Ratings':ratings,'Metascore':metascore})
df_1
# Out:
#      Serial no.                                         Movie Name  \
# 0            1.                                   The Dark Knight
# 1            2.     The Lord of the Rings: The Return of the King
# 2            3.               Spider-Man: Across the Spider-Verse
# 3            4.                                         Inception
# 4            5.   The Lord of the Rings: The Fellowship of the ...
# ...         ...                                                ...
# 1755     1,756.                                            Laxmii
# 1756     1,757.                                 Alone in the Dark
# 1757     1,758.                                     The Prototype
# 1758     1,759.                                 House of the Dead
# 1759     1,760.                                             Radhe
#
#                Director 1             Director 2            Director 3  \
# 0      Christopher Nolan                     N/A                   N/A
# 1          Peter Jackson                     N/A                   N/A
# 2      Joaquim Dos Santos            Kemp Powers   Justin K. Thompson
# 3      Christopher Nolan                     N/A                   N/A
# 4          Peter Jackson                     N/A                   N/A
# ...                   ...                    ...                   ...
# 1755     Raghava Lawrence   Balakrishnan Thevar                    N/A
# 1756            Uwe Boll                     N/A                   N/A
# 1757       Marcelo Grion                     N/A                   N/A
# 1758            Uwe Boll                     N/A                   N/A
# 1759         Prabhu Deva                     N/A                   N/A
#
#      Director 4 Director 5 Director 6 Duration Year of Release Ratings  \
# 0           N/A        N/A        N/A      152          (2008)     9.0
# 1           N/A        N/A        N/A      201          (2003)     9.0
# 2           N/A        N/A        N/A      140          (2023)     8.9
# 3           N/A        N/A        N/A      148          (2010)     8.8
# 4           N/A        N/A        N/A      178          (2001)     8.8
# ...         ...        ...        ...      ...             ...     ...
# 1755        N/A        N/A        N/A      141          (2020)     2.5
# 1756        N/A        N/A        N/A       96          (2005)     2.4
# 1757        N/A        N/A        N/A       97          (2022)     2.4
# 1758        N/A        N/A        N/A       90          (2003)     2.1
# 1759        N/A        N/A        N/A      109          (2021)     1.9
#
#      Metascore
# 0           84
# 1           94
# 2           86
# 3           74
# 4           92
# ...        ...
# 1755       Nan
# 1756         9
# 1757       Nan
# 1758        15
# 1759       Nan
#
# [1760 rows x 12 columns]

# %%
df_2=pd.DataFrame({'Movie Name':movie_name,'Star 1':star_1,'Star 2':star_2,'Star 3':star_3,'Star 4':star_4,'Votes':votes,'Genre 1':genre_1,'Genre 2':genre_2,'Genre 3':genre_3,'Gross Collection':gross_collection,'Popularity':popularity, 'Certification':certification})
df_2
# Out:
#                                              Movie Name              Star 1  \
# 0                                      The Dark Knight       Christian Bale
# 1        The Lord of the Rings: The Return of the King          Elijah Wood
# 2                  Spider-Man: Across the Spider-Verse        Shameik Moore
# 3                                            Inception    Leonardo DiCaprio
# 4      The Lord of the Rings: The Fellowship of the ...         Elijah Wood
# ...                                                 ...                 ...
# 1755                                            Laxmii         Akshay Kumar
# 1756                                 Alone in the Dark     Christian Slater
# 1757                                     The Prototype    Mark Vasconcellos
# 1758                                 House of the Dead      Jonathan Cherry
# 1759                                             Radhe          Salman Khan
#
#                      Star 2              Star 3                Star 4  \
# 0              Heath Ledger       Aaron Eckhart         Michael Caine
# 1           Viggo Mortensen        Ian McKellen         Orlando Bloom
# 2          Hailee Steinfeld   Brian Tyree Henry     Luna Lauren Velez
# 3      Joseph Gordon-Levitt         Elliot Page          Ken Watanabe
# 4              Ian McKellen       Orlando Bloom             Sean Bean
# ...                     ...                 ...                   ...
# 1755           Kiara Advani       Sharad Kelkar      Ashwini Kalsekar
# 1756              Tara Reid       Stephen Dorff       Frank C. Turner
# 1757         Frank Spinelli    Victoria De Mare   Juan Antonio Devoto
# 1758           Tyron Leitso        Clint Howard            Ona Grauer
# 1759           Disha Patani       Randeep Hooda         Jackie Shroff
#
#             Votes    Genre 1     Genre 2     Genre 3 Gross Collection  \
# 0      2,735,456      Action       Crime       Drama         $534.86M
# 1      1,896,201      Action   Adventure       Drama         $377.85M
# 2         174,379  Animation      Action   Adventure              N/A
# 3      2,427,522      Action   Adventure      Sci-Fi         $292.58M
# 4      1,924,654      Action   Adventure       Drama         $315.54M
# ...           ...        ...         ...         ...              ...
# 1755       58,107     Action      Comedy      Horror              N/A
# 1756      46,458      Action      Horror      Sci-Fi           $5.18M
# 1757       36,537     Action      Sci-Fi    Thriller              N/A
# 1758      38,073      Action   Adventure      Horror          $10.25M
# 1759      179,014     Action       Crime    Thriller              N/A
#
#      Popularity Certification
# 0           791         PG-13
# 1          3481         PG-13
# 2            72         PG-13
# 3           884         PG-13
# 4         15311            PG
# ...         ...           ...
# 1755                       PG
# 1756        234             R
# 1757                        R
# 1758        201             R
# 1759                        R
#
# [1760 rows x 12 columns]

# %%
#Saving both the DataFrame into csv file 

df_1.to_csv('dataset1.csv')
df_2.to_csv('dataset2.csv')

# %% [markdown]
# ## Phase-1 of the capstone project is completed here.
